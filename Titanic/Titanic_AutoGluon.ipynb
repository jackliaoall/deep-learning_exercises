# %%
#Install Autogluon
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# !pip install --upgrade "mxnet<2.0.0"
# !pip install --pre autogluon
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/cd/6f/43037c7bcc8bd8ba7c9074256b1a11596daa15555808ec748048c1507f08/pip-21.1.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.6MB 4.1MB/s
# Installing collected packages: pip
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# Successfully installed pip-21.1.1
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (56.1.0)
# Collecting setuptools
#   Downloading setuptools-56.2.0-py3-none-any.whl (785 kB)
#      |████████████████████████████████| 785 kB 4.3 MB/s
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 56.1.0
#     Uninstalling setuptools-56.1.0:
#       Successfully uninstalled setuptools-56.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed setuptools-56.2.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Collecting mxnet<2.0.0
#   Downloading mxnet-1.8.0.post0-py2.py3-none-manylinux2014_x86_64.whl (46.9 MB)
#      |████████████████████████████████| 46.9 MB 54 kB/s
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet<2.0.0) (1.19.5)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet<2.0.0) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet<2.0.0) (2.10)
# Installing collected packages: graphviz, mxnet
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.8.0.post0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Collecting autogluon
#   Downloading autogluon-0.2.1b20210515-py3-none-any.whl (6.0 kB)
# Collecting autogluon.core==0.2.1b20210515
#   Downloading autogluon.core-0.2.1b20210515-py3-none-any.whl (335 kB)
#      |████████████████████████████████| 335 kB 4.0 MB/s
# Collecting autogluon.extra==0.2.1b20210515
#   Downloading autogluon.extra-0.2.1b20210515-py3-none-any.whl (24 kB)
# Collecting autogluon.vision==0.2.1b20210515
#   Downloading autogluon.vision-0.2.1b20210515-py3-none-any.whl (32 kB)
# Collecting autogluon.features==0.2.1b20210515
#   Downloading autogluon.features-0.2.1b20210515-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 3.6 MB/s
# Collecting autogluon.text==0.2.1b20210515
#   Downloading autogluon.text-0.2.1b20210515-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 3.4 MB/s
# Collecting autogluon.mxnet==0.2.1b20210515
#   Downloading autogluon.mxnet-0.2.1b20210515-py3-none-any.whl (29 kB)
# Collecting autogluon.tabular[all]==0.2.1b20210515
#   Downloading autogluon.tabular-0.2.1b20210515-py3-none-any.whl (267 kB)
#      |████████████████████████████████| 267 kB 6.0 MB/s
# Collecting paramiko>=2.4
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 7.2 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (3.2.2)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (0.8.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (2.23.0)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (5.1.1)
# Collecting distributed>=2.6.0
#   Downloading distributed-2021.5.0-py3-none-any.whl (699 kB)
#      |████████████████████████████████| 699 kB 7.4 MB/s
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (4.41.1)
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (2.12.0)
# Requirement already satisfied: numpy==1.19.5 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (1.19.5)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (1.1.5)
# Collecting boto3
#   Downloading boto3-1.17.73-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 13.6 MB/s
# Collecting ConfigSpace==0.4.18
#   Downloading ConfigSpace-0.4.18.tar.gz (950 kB)
#      |████████████████████████████████| 950 kB 12.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (1.3)
# Requirement already satisfied: dill==0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (0.3.3)
# Collecting scikit-learn<0.25,>=0.23.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.2.1b20210515->autogluon) (0.29.23)
# Collecting scipy<1.7,>=1.5.4
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 125 kB/s
# Collecting gluoncv<0.11,>=0.10.1.post0
#   Downloading gluoncv-0.10.1.post0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 48.9 MB/s
# Collecting openml
#   Downloading openml-0.12.1.tar.gz (115 kB)
#      |████████████████████████████████| 115 kB 68.2 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.2.1b20210515->autogluon) (3.6.4)
# Requirement already satisfied: Pillow<=8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.mxnet==0.2.1b20210515->autogluon) (7.1.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210515->autogluon) (2.5.1)
# Collecting psutil<5.9,>=5.7.3
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 49.6 MB/s
# Collecting lightgbm<4.0,>=3.0
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 42.0 MB/s
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.8.1+cu101)
# Collecting fastai<3.0,>=2.0
#   Downloading fastai-2.3.1-py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 69.2 MB/s
# Collecting catboost<0.26,>=0.24.0
#   Downloading catboost-0.25.1-cp37-none-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 10.0 kB/s
# Collecting xgboost<1.4,>=1.3.2
#   Downloading xgboost-1.3.3-py3-none-manylinux2010_x86_64.whl (157.5 MB)
#      |████████████████████████████████| 157.5 MB 63 kB/s
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon.text==0.2.1b20210515->autogluon) (3.0.0)
# Collecting autogluon-contrib-nlp==0.0.1b20210201
#   Downloading autogluon_contrib_nlp-0.0.1b20210201-py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 66.6 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210515->autogluon) (3.12.4)
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 36.0 MB/s
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210515->autogluon) (2019.12.20)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting sacremoses>=0.0.38
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 32.6 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-1.5.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.6 MB/s
# Collecting sentencepiece==0.1.95
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 28.2 MB/s
# Collecting flake8
#   Downloading flake8-3.9.2-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.8 MB/s
# Collecting d8<1.0,>=0.0.2
#   Downloading d8-0.0.2.post0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.18->autogluon.core==0.2.1b20210515->autogluon) (2.4.7)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.2.1b20210515->autogluon) (0.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.15.0)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 51.9 MB/s
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210515->autogluon) (1.5.12)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (0.11.1)
# Collecting cloudpickle>=1.5.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (8.0.0)
# Collecting dask>=2.6.0
#   Downloading dask-2021.5.0-py3-none-any.whl (960 kB)
#      |████████████████████████████████| 960 kB 33.2 MB/s
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (2.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (56.2.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (2.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (1.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (3.13)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (1.0.2)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.5.0-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 48.7 MB/s
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (21.1.1)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (2.2.4)
# Collecting fastcore<1.4,>=1.3.8
#   Downloading fastcore-1.3.20-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.2 MB/s
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (0.9.1+cu101)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (20.9)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.0.0)
# Collecting portalocker
#   Downloading portalocker-2.3.0-py2.py3-none-any.whl (15 kB)
# Collecting autocfg
#   Downloading autocfg-0.0.8-py3-none-any.whl (13 kB)
# Collecting decord
#   Downloading decord-0.5.2-py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 74 kB/s
# Collecting tensorboardx
#   Downloading tensorboardX-2.2-py2.py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 75.2 MB/s
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.11,>=0.10.1.post0->autogluon.extra==0.2.1b20210515->autogluon) (4.1.2.30)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (0.36.2)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx<3.0,>=2.3->autogluon.tabular[all]==0.2.1b20210515->autogluon) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.2.1b20210515->autogluon) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.2.1b20210515->autogluon) (2018.9)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 22.7 MB/s
# Collecting cryptography>=2.5
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 29.5 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.2.1b20210515->autogluon) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.2.1b20210515->autogluon) (2.20)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.2.1b20210515->autogluon) (1.0.1)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (0.8.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210515->autogluon) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210515->autogluon) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210515->autogluon) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.2.1b20210515->autogluon) (2.10)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.2.1b20210515->autogluon) (1.0.1)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.2 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.21.0,>=1.20.73
#   Downloading botocore-1.20.73-py2.py3-none-any.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 31.9 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.5 MB/s
# Collecting immutables>=0.9
#   Downloading immutables-0.15-cp37-cp37m-manylinux1_x86_64.whl (101 kB)
#      |████████████████████████████████| 101 kB 7.5 MB/s
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pyflakes<2.4.0,>=2.3.0
#   Downloading pyflakes-2.3.1-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 4.1 MB/s
# Collecting pycodestyle<2.8.0,>=2.7.0
#   Downloading pycodestyle-2.7.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 468 kB/s
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210515->autogluon) (5.0.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.2.1b20210515->autogluon) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.2.1b20210515->autogluon) (1.3.1)
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting minio
#   Downloading minio-7.0.3-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.8 MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.2.1b20210515->autogluon) (1.3.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210515->autogluon) (8.7.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210515->autogluon) (1.10.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210515->autogluon) (21.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210515->autogluon) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.2.1b20210515->autogluon) (0.7.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.2.1b20210515->autogluon) (1.3)
# Collecting portalocker
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: ConfigSpace, contextvars, openml, liac-arff
#   Building wheel for ConfigSpace (PEP 517) ... done
#   Created wheel for ConfigSpace: filename=ConfigSpace-0.4.18-cp37-cp37m-linux_x86_64.whl size=2880008 sha256=f0ece2ef163ed47a96a3a32ede6a7da30f7c6e786a4dc1b95037d505748e1105
#   Stored in directory: /root/.cache/pip/wheels/36/f7/0f/36f368c419ea1a8024fc3d6c078c3111dfef43fa1d14cfebe0
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=45c9b3f14fb2a47b26234b0bc7b992e9e77a5bf3eb5c8afdae350058cd543b67
#   Stored in directory: /root/.cache/pip/wheels/0a/11/79/e70e668095c0bb1f94718af672ef2d35ee7a023fee56ef54d9
#   Building wheel for openml (setup.py) ... done
#   Created wheel for openml: filename=openml-0.12.1-py3-none-any.whl size=132143 sha256=61df07e10ec7167fd51342e59a389c1062d8dcbc11a11b1bddaf6b49df0a1e65
#   Stored in directory: /root/.cache/pip/wheels/ea/77/16/c4f01efd89dd4a30524ec3bb91ba344b2c890031c0a85653b2
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=781ec942958c86c7eb3d6a02b1c4c01520f83cb10e1c18467111d4ac5e249baf
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
# Successfully built ConfigSpace contextvars openml liac-arff
# Installing collected packages: urllib3, locket, jmespath, partd, fsspec, cloudpickle, botocore, threadpoolctl, scipy, s3transfer, pynacl, psutil, dask, cryptography, bcrypt, scikit-learn, paramiko, distributed, ConfigSpace, boto3, xmltodict, pyflakes, pycodestyle, portalocker, minio, mccabe, liac-arff, immutables, autogluon.core, yacs, xxhash, tokenizers, tensorboardx, sentencepiece, sacremoses, sacrebleu, openml, flake8, fastcore, decord, contextvars, autogluon.features, autocfg, xgboost, lightgbm, gluoncv, fastai, d8, catboost, autogluon.tabular, autogluon.mxnet, autogluon-contrib-nlp, autogluon.vision, autogluon.text, autogluon.extra, autogluon
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 0.90
#     Uninstalling xgboost-0.90:
#       Successfully uninstalled xgboost-0.90
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: fastai
#     Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed ConfigSpace-0.4.18 autocfg-0.0.8 autogluon-0.2.1b20210515 autogluon-contrib-nlp-0.0.1b20210201 autogluon.core-0.2.1b20210515 autogluon.extra-0.2.1b20210515 autogluon.features-0.2.1b20210515 autogluon.mxnet-0.2.1b20210515 autogluon.tabular-0.2.1b20210515 autogluon.text-0.2.1b20210515 autogluon.vision-0.2.1b20210515 bcrypt-3.2.0 boto3-1.17.73 botocore-1.20.73 catboost-0.25.1 cloudpickle-1.6.0 contextvars-2.4 cryptography-3.4.7 d8-0.0.2.post0 dask-2021.5.0 decord-0.5.2 distributed-2021.5.0 fastai-2.3.1 fastcore-1.3.20 flake8-3.9.2 fsspec-2021.5.0 gluoncv-0.10.1.post0 immutables-0.15 jmespath-0.10.0 liac-arff-2.5.0 lightgbm-3.2.1 locket-0.2.1 mccabe-0.6.1 minio-7.0.3 openml-0.12.1 paramiko-2.7.2 partd-1.2.0 portalocker-2.0.0 psutil-5.8.0 pycodestyle-2.7.0 pyflakes-2.3.1 pynacl-1.4.0 s3transfer-0.4.2 sacrebleu-1.5.1 sacremoses-0.0.45 scikit-learn-0.24.2 scipy-1.6.3 sentencepiece-0.1.95 tensorboardx-2.2 threadpoolctl-2.1.0 tokenizers-0.9.4 urllib3-1.25.11 xgboost-1.3.3 xmltodict-0.12.0 xxhash-2.0.2 yacs-0.1.8
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

train_data = TabularDataset('train.csv')
id, label = 'PassengerId', 'Survived'

#train
predictor = TabularPredictor(label=label).fit(
    train_data.drop(columns=[id]))
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210515_095815/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210515_095815/"
# AutoGluon Version:  0.2.1b20210515
# Train Data Rows:    891
# Train Data Columns: 10
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12717.98 MB
# 	Train Data (Original)  Memory Usage: 0.31 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Name']
# 			CountVectorizer fit with vocabulary size = 8
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 2 | ['Age', 'Fare']
# 		('int', [])          : 3 | ['Pclass', 'SibSp', 'Parch']
# 		('object', [])       : 4 | ['Sex', 'Ticket', 'Cabin', 'Embarked']
# 		('object', ['text']) : 1 | ['Name']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  4 | ['Sex', 'Ticket', 'Cabin', 'Embarked']
# 		('float', [])                       :  2 | ['Age', 'Fare']
# 		('int', [])                         :  3 | ['Pclass', 'SibSp', 'Parch']
# 		('int', ['binned', 'text_special']) : 12 | ['Name.char_count', 'Name.word_count', 'Name.capital_ratio', 'Name.lower_ratio', 'Name.special_ratio', ...]
# 		('int', ['text_ngram'])             :  9 | ['__nlp__.henry', '__nlp__.john', '__nlp__.master', '__nlp__.miss', '__nlp__.mr', ...]
# 	0.9s = Fit runtime
# 	10 features in original data used to generate 30 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.07 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.98s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 712, Val Rows: 179
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.6536	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.6927	 = Validation accuracy score
# 	0.01s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /usr/local/lib/python3.7/dist-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# 	0.8156	 = Validation accuracy score
# 	1.14s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.8268	 = Validation accuracy score
# 	0.24s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.8268	 = Validation accuracy score
# 	0.76s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.8156	 = Validation accuracy score
# 	0.84s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.838	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.8156	 = Validation accuracy score
# 	0.75s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.8156	 = Validation accuracy score
# 	0.76s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 8: early stopping
# 	0.8101	 = Validation accuracy score
# 	4.52s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.8212	 = Validation accuracy score
# 	0.41s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.8212	 = Validation accuracy score
# 	7.03s	 = Training runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.8268	 = Validation accuracy score
# 	0.52s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.8603	 = Validation accuracy score
# 	0.48s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 21.44s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210515_095815/")

# %%
import pandas as pd

#make prediction
test_data = TabularDataset('test.csv')
preds = predictor.predict(test_data.drop(columns=[id]))
submission = pd.DataFrame({id: test_data[id], label:preds})
submission.to_csv('submission.csv', index=False)
# Out:
# Loaded data from: test.csv | Columns = 11 / 11 | Rows = 418 -> 418
